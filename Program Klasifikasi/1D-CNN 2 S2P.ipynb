# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, confusion_matrix
import numpy as np
import os
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define paths
base_dir = '/content/drive/MyDrive/Colab Notebooks/npy/S2P'
korosi_dir = os.path.join(base_dir, 'Korosi')
tidak_korosi_dir = os.path.join(base_dir, 'TidakKorosi')

# Initialize lists for data and labels
data = []
labels = []

# Helper function to load and process each file
def load_file(file_path):
    # Assuming the data is in CSV format with a single column
    return np.load(file_path)

# Load data from 'Korosi' folder
for filename in os.listdir(korosi_dir):
    file_path = os.path.join(korosi_dir, filename)
    file_data = load_file(file_path)
    data.append(file_data)
    labels.append('Berkarat')

# Load data from 'Tidak Korosi' folder
for filename in os.listdir(tidak_korosi_dir):
    file_path = os.path.join(tidak_korosi_dir, filename)
    file_data = load_file(file_path)
    data.append(file_data)
    labels.append('Tidak Berkarat')

# %%
# Convert lists to numpy arrays
X = np.array(data)
y = np.array(labels)

# Encode the labels (0: TidakBerkarat, 1: Berkarat)
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# First split: separate out test set (10% of total data)
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Second split: separate validation set from remaining data (22.22% of remaining data, which is 20% of total)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2222, random_state=42)

# Reshape the input data to add the channel dimension
X_train = X_train.reshape(-1, 1024, 1)
X_val = X_val.reshape(-1, 1024, 1)
X_test = X_test.reshape(-1, 1024, 1)

# 2 Layers
model = Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(1024, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(64, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 1022, 32)          128
#
#  max_pooling1d_3 (MaxPoolin  (None, 511, 32)           0
#  g1D)
#
#  conv1d_7 (Conv1D)           (None, 509, 64)           6208
#
#  flatten_3 (Flatten)         (None, 32576)             0
#
#  dense_3 (Dense)             (None, 1)                 32577
#
# =================================================================
# Total params: 38913 (152.00 KB)
# Trainable params: 38913 (152.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 56ms/step - loss: 0.6837 - accuracy: 0.5863 - val_loss: 0.6620 - val_accuracy: 0.9792
# Epoch 2/50
# 11/11 [==============================] - 0s 36ms/step - loss: 0.6418 - accuracy: 0.6607 - val_loss: 0.6004 - val_accuracy: 1.0000
# Epoch 3/50
# 11/11 [==============================] - 0s 46ms/step - loss: 0.5515 - accuracy: 1.0000 - val_loss: 0.4719 - val_accuracy: 1.0000
# Epoch 4/50
# 11/11 [==============================] - 0s 37ms/step - loss: 0.4019 - accuracy: 1.0000 - val_loss: 0.2963 - val_accuracy: 1.0000
# Epoch 5/50
# 11/11 [==============================] - 0s 36ms/step - loss: 0.2248 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 1.0000
# Epoch 6/50
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0931 - accuracy: 1.0000 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 7/50
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 1.0000
# Epoch 8/50
# 11/11 [==============================] - 0s 40ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 9/50
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 10/50
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 11/50
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 12/50
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 13/50
# 11/11 [==============================] - 0s 41ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 14/50
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 15/50
# 11/11 [==============================] - 0s 39ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 16/50
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 17/50
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 18/50
# 11/11 [==============================] - 0s 38ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 19/50
# 11/11 [==============================] - 0s 36ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 20/50
# 11/11 [==============================] - 0s 44ms/step - loss: 9.7377e-04 - accuracy: 1.0000 - val_loss: 9.5490e-04 - val_accuracy: 1.0000
# Epoch 21/50
# 11/11 [==============================] - 1s 62ms/step - loss: 8.4681e-04 - accuracy: 1.0000 - val_loss: 8.6065e-04 - val_accuracy: 1.0000
# Epoch 22/50
# 11/11 [==============================] - 1s 66ms/step - loss: 7.5101e-04 - accuracy: 1.0000 - val_loss: 7.5538e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 11/11 [==============================] - 1s 64ms/step - loss: 6.6896e-04 - accuracy: 1.0000 - val_loss: 6.7701e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 11/11 [==============================] - 1s 69ms/step - loss: 5.9949e-04 - accuracy: 1.0000 - val_loss: 6.0607e-04 - val_accuracy: 1.0000
# Epoch 25/50
# 11/11 [==============================] - 1s 60ms/step - loss: 5.3781e-04 - accuracy: 1.0000 - val_loss: 5.4671e-04 - val_accuracy: 1.0000
# Epoch 26/50
# 11/11 [==============================] - 1s 63ms/step - loss: 4.8528e-04 - accuracy: 1.0000 - val_loss: 4.9830e-04 - val_accuracy: 1.0000
# Epoch 27/50
# 11/11 [==============================] - 1s 66ms/step - loss: 4.4353e-04 - accuracy: 1.0000 - val_loss: 4.5062e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 11/11 [==============================] - 0s 36ms/step - loss: 3.9974e-04 - accuracy: 1.0000 - val_loss: 4.1033e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 11/11 [==============================] - 0s 42ms/step - loss: 3.6213e-04 - accuracy: 1.0000 - val_loss: 3.7586e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 11/11 [==============================] - 1s 57ms/step - loss: 3.3284e-04 - accuracy: 1.0000 - val_loss: 3.4304e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 11/11 [==============================] - 1s 64ms/step - loss: 3.0374e-04 - accuracy: 1.0000 - val_loss: 3.1618e-04 - val_accuracy: 1.0000
# Epoch 32/50
# 11/11 [==============================] - 0s 43ms/step - loss: 2.8033e-04 - accuracy: 1.0000 - val_loss: 2.9070e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 11/11 [==============================] - 1s 58ms/step - loss: 2.5674e-04 - accuracy: 1.0000 - val_loss: 2.7127e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 11/11 [==============================] - 0s 38ms/step - loss: 2.3842e-04 - accuracy: 1.0000 - val_loss: 2.4897e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 11/11 [==============================] - 0s 38ms/step - loss: 2.2235e-04 - accuracy: 1.0000 - val_loss: 2.3291e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 11/11 [==============================] - 0s 38ms/step - loss: 2.0716e-04 - accuracy: 1.0000 - val_loss: 2.1521e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 11/11 [==============================] - 0s 40ms/step - loss: 1.9222e-04 - accuracy: 1.0000 - val_loss: 2.0098e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 11/11 [==============================] - 0s 36ms/step - loss: 1.7836e-04 - accuracy: 1.0000 - val_loss: 1.8870e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 11/11 [==============================] - 0s 39ms/step - loss: 1.6651e-04 - accuracy: 1.0000 - val_loss: 1.7589e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 11/11 [==============================] - 0s 36ms/step - loss: 1.5526e-04 - accuracy: 1.0000 - val_loss: 1.6527e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 11/11 [==============================] - 0s 37ms/step - loss: 1.4623e-04 - accuracy: 1.0000 - val_loss: 1.5488e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 11/11 [==============================] - 0s 40ms/step - loss: 1.3759e-04 - accuracy: 1.0000 - val_loss: 1.4642e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 11/11 [==============================] - 0s 37ms/step - loss: 1.2950e-04 - accuracy: 1.0000 - val_loss: 1.3741e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 11/11 [==============================] - 0s 41ms/step - loss: 1.2125e-04 - accuracy: 1.0000 - val_loss: 1.3100e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 11/11 [==============================] - 0s 39ms/step - loss: 1.1527e-04 - accuracy: 1.0000 - val_loss: 1.2296e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 11/11 [==============================] - 0s 37ms/step - loss: 1.0838e-04 - accuracy: 1.0000 - val_loss: 1.1625e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 11/11 [==============================] - 0s 38ms/step - loss: 1.0269e-04 - accuracy: 1.0000 - val_loss: 1.1032e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 11/11 [==============================] - 0s 37ms/step - loss: 9.7273e-05 - accuracy: 1.0000 - val_loss: 1.0504e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 11/11 [==============================] - 1s 47ms/step - loss: 9.2755e-05 - accuracy: 1.0000 - val_loss: 9.9113e-05 - val_accuracy: 1.0000
# Epoch 50/50
# 11/11 [==============================] - 1s 62ms/step - loss: 8.7841e-05 - accuracy: 1.0000 - val_loss: 9.4705e-05 - val_accuracy: 1.0000

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy*100:.2f}%')
# Out:
# 2/2 [==============================] - 0s 13ms/step - loss: 9.4705e-05 - accuracy: 1.0000
# Accuracy: 100.00%

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Predict and calculate metrics
y_pred = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 2/2 [==============================] - 0s 9ms/step

# %%
f1 = f1_score(y_test, y_pred)

print(f'F1 Score: {f1}')
# Out:
# F1 Score: 1.0

# %%
precision = precision_score(y_test, y_pred)

print(f'Precision: {precision}')
# Out:
# Precision: 1.0

# %%
recall = recall_score(y_test, y_pred)

print(f'Recall: {recall}')
# Out:
# Recall: 1.0

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Confusion Matrix:
# [[22  0]
#  [ 0 26]]

# %%
# prompt: plot the confusion matrix

import seaborn as sns
import matplotlib.pyplot as plt

# Get the class labels
class_labels = ['Tidak Berkarat', 'Berkarat']

# Create the confusion matrix visualization
sns.heatmap(conf_matrix, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels)

# Set the title and show the plot
plt.title('Confusion Matrix')
plt.show()
