# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, confusion_matrix
import numpy as np
import os
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define paths
base_dir = '/content/drive/MyDrive/Colab Notebooks/npy/S1P'
korosi_dir = os.path.join(base_dir, 'Korosi')
tidak_korosi_dir = os.path.join(base_dir, 'TidakKorosi')

# Initialize lists for data and labels
data = []
labels = []

# Helper function to load and process each file
def load_file(file_path):
    # Assuming the data is in CSV format with a single column
    return np.load(file_path)

# Load data from 'Korosi' folder
for filename in os.listdir(korosi_dir):
    file_path = os.path.join(korosi_dir, filename)
    file_data = load_file(file_path)
    data.append(file_data)
    labels.append('Berkarat')

# Load data from 'Tidak Korosi' folder
for filename in os.listdir(tidak_korosi_dir):
    file_path = os.path.join(tidak_korosi_dir, filename)
    file_data = load_file(file_path)
    data.append(file_data)
    labels.append('Tidak Berkarat')

# %%
# Convert lists to numpy arrays
X = np.array(data)
y = np.array(labels)

# Encode the labels (0: TidakBerkarat, 1: Berkarat)
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# First split: separate out test set (10% of total data)
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Second split: separate validation set from remaining data (22.22% of remaining data, which is 20% of total)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2222, random_state=42)

# Reshape the input data to add the channel dimension
X_train = X_train.reshape(-1, 1024, 1)
X_val = X_val.reshape(-1, 1024, 1)
X_test = X_test.reshape(-1, 1024, 1)

# Define the 1D CNN model
model = Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(1024, 1)))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 1022, 32)          128
#
#  flatten_1 (Flatten)         (None, 32704)             0
#
#  dense_1 (Dense)             (None, 1)                 32705
#
# =================================================================
# Total params: 32833 (128.25 KB)
# Trainable params: 32833 (128.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 34ms/step - loss: 0.6925 - accuracy: 0.4762 - val_loss: 0.6893 - val_accuracy: 0.5833
# Epoch 2/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.6894 - accuracy: 0.6369 - val_loss: 0.6837 - val_accuracy: 0.5833
# Epoch 3/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.6837 - accuracy: 0.5268 - val_loss: 0.6774 - val_accuracy: 0.7708
# Epoch 4/50
# 11/11 [==============================] - 0s 13ms/step - loss: 0.6774 - accuracy: 0.5327 - val_loss: 0.6697 - val_accuracy: 1.0000
# Epoch 5/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.6697 - accuracy: 0.8155 - val_loss: 0.6619 - val_accuracy: 1.0000
# Epoch 6/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.6598 - accuracy: 0.7202 - val_loss: 0.6458 - val_accuracy: 0.5833
# Epoch 7/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.6493 - accuracy: 0.7381 - val_loss: 0.6370 - val_accuracy: 1.0000
# Epoch 8/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.6330 - accuracy: 0.7024 - val_loss: 0.6196 - val_accuracy: 1.0000
# Epoch 9/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.6171 - accuracy: 0.9464 - val_loss: 0.6009 - val_accuracy: 1.0000
# Epoch 10/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6037 - accuracy: 0.8452 - val_loss: 0.5919 - val_accuracy: 0.9375
# Epoch 11/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5783 - accuracy: 0.9673 - val_loss: 0.5655 - val_accuracy: 0.6042
# Epoch 12/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.5672 - accuracy: 0.8780 - val_loss: 0.5450 - val_accuracy: 1.0000
# Epoch 13/50
# 11/11 [==============================] - 0s 14ms/step - loss: 0.5393 - accuracy: 0.9851 - val_loss: 0.5193 - val_accuracy: 0.9167
# Epoch 14/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.5258 - accuracy: 0.9762 - val_loss: 0.4994 - val_accuracy: 1.0000
# Epoch 15/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.5043 - accuracy: 0.9851 - val_loss: 0.4935 - val_accuracy: 0.9375
# Epoch 16/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.4771 - accuracy: 0.9911 - val_loss: 0.4566 - val_accuracy: 1.0000
# Epoch 17/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.4522 - accuracy: 0.9911 - val_loss: 0.4296 - val_accuracy: 1.0000
# Epoch 18/50
# 11/11 [==============================] - 0s 14ms/step - loss: 0.4488 - accuracy: 0.9732 - val_loss: 0.4078 - val_accuracy: 1.0000
# Epoch 19/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4224 - accuracy: 0.9435 - val_loss: 0.4264 - val_accuracy: 0.9167
# Epoch 20/50
# 11/11 [==============================] - 0s 14ms/step - loss: 0.4062 - accuracy: 0.9851 - val_loss: 0.3781 - val_accuracy: 1.0000
# Epoch 21/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.3766 - accuracy: 0.9940 - val_loss: 0.3510 - val_accuracy: 1.0000
# Epoch 22/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3643 - accuracy: 0.9911 - val_loss: 0.3436 - val_accuracy: 1.0000
# Epoch 23/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.3546 - accuracy: 0.9821 - val_loss: 0.3482 - val_accuracy: 1.0000
# Epoch 24/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3268 - accuracy: 0.9940 - val_loss: 0.2998 - val_accuracy: 1.0000
# Epoch 25/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3092 - accuracy: 0.9970 - val_loss: 0.2841 - val_accuracy: 1.0000
# Epoch 26/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2939 - accuracy: 0.9940 - val_loss: 0.2778 - val_accuracy: 1.0000
# Epoch 27/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2825 - accuracy: 0.9881 - val_loss: 0.2527 - val_accuracy: 1.0000
# Epoch 28/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.2680 - accuracy: 0.9940 - val_loss: 0.2715 - val_accuracy: 1.0000
# Epoch 29/50
# 11/11 [==============================] - 0s 14ms/step - loss: 0.2609 - accuracy: 0.9940 - val_loss: 0.2477 - val_accuracy: 1.0000
# Epoch 30/50
# 11/11 [==============================] - 0s 14ms/step - loss: 0.2376 - accuracy: 0.9940 - val_loss: 0.2142 - val_accuracy: 1.0000
# Epoch 31/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.2205 - accuracy: 0.9970 - val_loss: 0.2137 - val_accuracy: 1.0000
# Epoch 32/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.2186 - accuracy: 0.9911 - val_loss: 0.2069 - val_accuracy: 1.0000
# Epoch 33/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.2105 - accuracy: 0.9970 - val_loss: 0.2002 - val_accuracy: 1.0000
# Epoch 34/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1926 - accuracy: 0.9940 - val_loss: 0.1707 - val_accuracy: 1.0000
# Epoch 35/50
# 11/11 [==============================] - 0s 14ms/step - loss: 0.1798 - accuracy: 0.9970 - val_loss: 0.1611 - val_accuracy: 1.0000
# Epoch 36/50
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1765 - accuracy: 0.9970 - val_loss: 0.1562 - val_accuracy: 1.0000
# Epoch 37/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.1759 - accuracy: 0.9940 - val_loss: 0.1465 - val_accuracy: 1.0000
# Epoch 38/50
# 11/11 [==============================] - 0s 26ms/step - loss: 0.1551 - accuracy: 0.9970 - val_loss: 0.1413 - val_accuracy: 1.0000
# Epoch 39/50
# 11/11 [==============================] - 0s 24ms/step - loss: 0.1538 - accuracy: 0.9970 - val_loss: 0.1436 - val_accuracy: 1.0000
# Epoch 40/50
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1439 - accuracy: 0.9970 - val_loss: 0.1283 - val_accuracy: 1.0000
# Epoch 41/50
# 11/11 [==============================] - 0s 31ms/step - loss: 0.1396 - accuracy: 0.9970 - val_loss: 0.1191 - val_accuracy: 1.0000
# Epoch 42/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.1318 - accuracy: 0.9940 - val_loss: 0.1245 - val_accuracy: 1.0000
# Epoch 43/50
# 11/11 [==============================] - 0s 24ms/step - loss: 0.1220 - accuracy: 0.9970 - val_loss: 0.1082 - val_accuracy: 1.0000
# Epoch 44/50
# 11/11 [==============================] - 0s 25ms/step - loss: 0.1148 - accuracy: 0.9970 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 45/50
# 11/11 [==============================] - 0s 29ms/step - loss: 0.1104 - accuracy: 0.9970 - val_loss: 0.0945 - val_accuracy: 1.0000
# Epoch 46/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.1037 - accuracy: 0.9970 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 47/50
# 11/11 [==============================] - 0s 23ms/step - loss: 0.1004 - accuracy: 0.9970 - val_loss: 0.0887 - val_accuracy: 1.0000
# Epoch 48/50
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0964 - accuracy: 0.9970 - val_loss: 0.0921 - val_accuracy: 1.0000
# Epoch 49/50
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0963 - accuracy: 0.9970 - val_loss: 0.0823 - val_accuracy: 1.0000
# Epoch 50/50
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0868 - accuracy: 0.9970 - val_loss: 0.0742 - val_accuracy: 1.0000

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy*100:.2f}%')
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0742 - accuracy: 1.0000
# Accuracy: 100.00%

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Predict and calculate metrics
y_pred = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 2/2 [==============================] - 0s 7ms/step

# %%
f1 = f1_score(y_test, y_pred)

print(f'F1 Score: {f1}')
# Out:
# F1 Score: 1.0

# %%
precision = precision_score(y_test, y_pred)

print(f'Precision: {precision}')
# Out:
# Precision: 1.0

# %%
recall = recall_score(y_test, y_pred)

print(f'Recall: {recall}')
# Out:
# Recall: 1.0

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Confusion Matrix:
# [[22  0]
#  [ 0 26]]

# %%
# prompt: plot the confusion matrix

import seaborn as sns
import matplotlib.pyplot as plt

# Get the class labels
class_labels = ['Tidak Berkarat', 'Berkarat']

# Create the confusion matrix visualization
sns.heatmap(conf_matrix, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels)

# Set the title and show the plot
plt.title('Confusion Matrix')
plt.show()
