# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, confusion_matrix
import numpy as np
import os
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define paths
base_dir = '/content/drive/MyDrive/Colab Notebooks/npy/S2P'
korosi_dir = os.path.join(base_dir, 'Korosi')
tidak_korosi_dir = os.path.join(base_dir, 'TidakKorosi')

# Initialize lists for data and labels
data = []
labels = []

# Helper function to load and process each file
def load_file(file_path):
    # Assuming the data is in CSV format with a single column
    return np.load(file_path)

# Load data from 'Korosi' folder
for filename in os.listdir(korosi_dir):
    file_path = os.path.join(korosi_dir, filename)
    file_data = load_file(file_path)
    data.append(file_data)
    labels.append('Berkarat')

# Load data from 'Tidak Korosi' folder
for filename in os.listdir(tidak_korosi_dir):
    file_path = os.path.join(tidak_korosi_dir, filename)
    file_data = load_file(file_path)
    data.append(file_data)
    labels.append('Tidak Berkarat')

# %%
# Convert lists to numpy arrays
X = np.array(data)
y = np.array(labels)

# Encode the labels (0: TidakBerkarat, 1: Berkarat)
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# First split: separate out test set (10% of total data)
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Second split: separate validation set from remaining data (22.22% of remaining data, which is 20% of total)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2222, random_state=42)

# Reshape the input data to add the channel dimension
X_train = X_train.reshape(-1, 1024, 1)
X_val = X_val.reshape(-1, 1024, 1)
X_test = X_test.reshape(-1, 1024, 1)

# Define the 1D CNN model
model = Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(1024, 1)))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1022, 32)          128
#
#  flatten (Flatten)           (None, 32704)             0
#
#  dense (Dense)               (None, 1)                 32705
#
# =================================================================
# Total params: 32833 (128.25 KB)
# Trainable params: 32833 (128.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 44ms/step - loss: 0.6851 - accuracy: 0.5357 - val_loss: 0.6711 - val_accuracy: 1.0000
# Epoch 2/50
# 11/11 [==============================] - 0s 24ms/step - loss: 0.6590 - accuracy: 1.0000 - val_loss: 0.6406 - val_accuracy: 1.0000
# Epoch 3/50
# 11/11 [==============================] - 0s 26ms/step - loss: 0.6257 - accuracy: 0.7738 - val_loss: 0.5967 - val_accuracy: 0.5417
# Epoch 4/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.5911 - accuracy: 0.6458 - val_loss: 0.5884 - val_accuracy: 0.4583
# Epoch 5/50
# 11/11 [==============================] - 0s 28ms/step - loss: 0.5542 - accuracy: 0.7798 - val_loss: 0.5135 - val_accuracy: 1.0000
# Epoch 6/50
# 11/11 [==============================] - 0s 24ms/step - loss: 0.4881 - accuracy: 1.0000 - val_loss: 0.4559 - val_accuracy: 1.0000
# Epoch 7/50
# 11/11 [==============================] - 0s 27ms/step - loss: 0.4241 - accuracy: 1.0000 - val_loss: 0.3958 - val_accuracy: 1.0000
# Epoch 8/50
# 11/11 [==============================] - 0s 29ms/step - loss: 0.3945 - accuracy: 0.8869 - val_loss: 0.3307 - val_accuracy: 1.0000
# Epoch 9/50
# 11/11 [==============================] - 0s 31ms/step - loss: 0.3200 - accuracy: 1.0000 - val_loss: 0.3027 - val_accuracy: 1.0000
# Epoch 10/50
# 11/11 [==============================] - 0s 27ms/step - loss: 0.2542 - accuracy: 1.0000 - val_loss: 0.2235 - val_accuracy: 1.0000
# Epoch 11/50
# 11/11 [==============================] - 0s 29ms/step - loss: 0.2043 - accuracy: 1.0000 - val_loss: 0.1784 - val_accuracy: 1.0000
# Epoch 12/50
# 11/11 [==============================] - 0s 28ms/step - loss: 0.1728 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 1.0000
# Epoch 13/50
# 11/11 [==============================] - 0s 27ms/step - loss: 0.1351 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 1.0000
# Epoch 14/50
# 11/11 [==============================] - 0s 31ms/step - loss: 0.1101 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 15/50
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0885 - accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 1.0000
# Epoch 16/50
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0752 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 1.0000
# Epoch 17/50
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0629 - accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 18/50
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 1.0000
# Epoch 19/50
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0459 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 1.0000
# Epoch 20/50
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 21/50
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0354 - accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 1.0000
# Epoch 22/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0310 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 1.0000
# Epoch 23/50
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 24/50
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 25/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 26/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 27/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 28/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 29/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 30/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 31/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 32/50
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 33/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 34/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 35/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 36/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 37/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 38/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 39/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 40/50
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 41/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 42/50
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 43/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 44/50
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 45/50
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 46/50
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 47/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 48/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 49/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 50/50
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy*100:.2f}%')
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0044 - accuracy: 1.0000
# Accuracy: 100.00%

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Predict and calculate metrics
y_pred = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 2/2 [==============================] - 0s 12ms/step

# %%
f1 = f1_score(y_test, y_pred)

print(f'F1 Score: {f1}')
# Out:
# F1 Score: 1.0

# %%
precision = precision_score(y_test, y_pred)

print(f'Precision: {precision}')
# Out:
# Precision: 1.0

# %%
recall = recall_score(y_test, y_pred)

print(f'Recall: {recall}')
# Out:
# Recall: 1.0

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

print(f'Confusion Matrix:\n{conf_matrix}')
# Out:
# Confusion Matrix:
# [[22  0]
#  [ 0 26]]

# %%
# prompt: plot the confusion matrix

import seaborn as sns
import matplotlib.pyplot as plt

# Get the class labels
class_labels = ['Tidak Berkarat', 'Berkarat']

# Create the confusion matrix visualization
sns.heatmap(conf_matrix, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels)

# Set the title and show the plot
plt.title('Confusion Matrix')
plt.show()
